# %%
#y=mx+c

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
x=np.arange(-1,1,0.001)
yt=3*x+2 + np.random.randn(len(x))
y=3*x+2
plt.plot(x,yt,'o')
plt.plot(x,y,'r')

# %% [markdown]
# $
# L=\frac{1}{2}\sum_i^n(y_p^i-y_t^i)
# $

# %%
theta1 = 0.0
theta2 = 0.0
alpha =0.1

def yp(x):
    global theta1,theta2
    return theta1*x+theta2

plt.plot(x,yt,'o')
for i in range(100):
    theta1 = theta1 - alpha*np.average( (yp(x)-yt)*x )
    theta2 = theta2 - alpha*np.average( (yp(x)-yt) )
    if i%10==0:
        print(theta1,theta2)
        plt.plot(x,theta1*x+theta2,'r')
# Out:
# 0.098406984593969 0.1998659171941788
# 0.9193280257727277 1.3716354922418643
# 1.5045304513695092 1.780422876224895
# 1.9215819433435246 1.9231125980838968
# 2.2187581109319026 1.9729754345674835
# 2.430501218164444 1.990439914132386
# 2.5813668786607447 1.9965852500134953
# 2.688856014719498 1.9987677873536471
# 2.7654395390468416 1.9995571414614592
# 2.820003320638992 1.999852571168381

# %%
a=np.arange(3)

# %%
# Out:
# -0.7548103251659967

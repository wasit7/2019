# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
n=200
def normal(n):
    return np.random.randn(n)
x1=np.concatenate((normal(n)-2,normal(n)+2),axis=None)
x2=np.concatenate((normal(n)-2,normal(n)+2),axis=None)
y=np.ones(2*n)
y[:n]=-1
plt.plot(x1[y==-1],x2[y==-1],'or')
plt.plot(x1[y==1],x2[y==1],'ob')

# %%
theta1 = 0.0
theta2 = 0.0
theta3 = 0.0
alpha =0.1

def yp(x1,x2):
    global theta1,theta2,theta3
    z=theta1*x1 + theta2*x2 +theta3
    return np.tanh(z)

for i in range(100):
    theta1 = theta1 - alpha*np.average( ..... )
    theta2 = theta2 - alpha*np.average( ... )
    theta3 = theta3 - alpha*np.average( (yp(x)-yt)*(1-yp*yp) )

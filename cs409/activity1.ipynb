# %% [markdown]
# # Activity1

# %% [markdown]
# <img src="69538996_646951485714042_6432569302288695296_n.jpg">
# <img src="69015413_550876852117352_3547953289293201408_n.jpg">

# %% [markdown]
# $$
# L=\theta^2 - \theta+1
# $$

# %%
theta = 1.0
alpha =0.3
for i in range(10):
    theta = theta - alpha*(2*theta-1)
    print(theta)
# Out:
# 0.7
# 0.58
# 0.532
# 0.5128
# 0.50512
# 0.502048
# 0.5008192
# 0.50032768
# 0.5001310720000001
# 0.5000524288

# %% [markdown]
# <img src="a3_fig1.jpg">
# <img src="a3_fig2.jpg">

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
n=200
def normal(n):
    return np.random.randn(n)
x1=np.concatenate((normal(n)-2,normal(n)+2),axis=None)
x2=np.concatenate((normal(n)-2,normal(n)+2),axis=None)
yt=np.ones(2*n)
yt[:n]=-1
plt.plot(x1[yt==-1],x2[yt==-1],'or')
plt.plot(x1[yt==1],x2[yt==1],'ob')

# %%
import numpy as np
from matplotlib import pyplot as plt
step = 0.2
mx2, mx1 = np.mgrid[slice(-6,6, step),
                    slice(-6,6, step)]

theta1 = 0.0
theta2 = 0.0
theta3 = 0.0
alpha =0.1

def func_yp(x1,x2):
    global theta1,theta2,theta3
    z=theta1*x1 + theta2*x2 +theta3
    return np.tanh(z)

plt.plot(x1[yt==-1],x2[yt==-1],'or')
plt.plot(x1[yt==1],x2[yt==1],'ob')
for i in range(100):
    yp=func_yp(x1,x2)
    theta1 = theta1 - alpha*np.average( (yp-yt)*(1-yp*yp)*x1 )
    theta2 = theta2 - alpha*np.average( (yp-yt)*(1-yp*yp)*x2 )
    theta3 = theta3 - alpha*np.average( (yp-yt)*(1-yp*yp ))
    if i%10==0:
        print(theta1,theta2,theta3)
        #plt.plot(x,theta1*x+theta2,'r')
cmap = plt.get_cmap('PuOr')
plt.pcolormesh(mx1, mx2, func_yp(mx1,mx2), cmap=cmap)
# Out:
# 0.20157514259885612 0.19841985604184764 0.0
# 0.3568715863401377 0.35864920994151556 -0.00495561426234302
# 0.4142908302437897 0.42034992831260587 -0.006427590706351267
# 0.4521233491000285 0.46196436842024846 -0.007006521976369253
# 0.48087763470572364 0.4941218822867318 -0.007172183605410918
# 0.5043083048692036 0.5206490471037433 -0.007107054924461649
# 0.5242129385573124 0.5433930684919605 -0.006900148112823495
# 0.5415985463023342 0.5633978365531963 -0.006601228245650493
# 0.55708862085811 0.5813155125067676 -0.006240651446482209
# 0.5710971319488536 0.5975830424607919 -0.005838087952946424
